# %% [markdown]
# ## Students Information
#
# Please enter the names and IDs of the two students below:
#
# 1. **Name**: [Enter Student 1 Name Here]
#    **ID**: `9XXXXXX`
#
# 2. **Name**: [Enter Student 2 Name Here]
#    **ID**: `9XXXXXX`

# %% [markdown]
# ## Students Instructions
#
# This is your last graded lab assignment, as you put the work you have studied in the lectures in action, please take this opportunity to enhance your understanding of the concepts and hone your skills. As you work on your assignment, please keep the following instructions in mind:
#
# - Clearly state your personal information where indicated.
# - Be ready with your work before the time of the next discussion slot in the schedule.
# - Plagiarism will be met with penalties, refrain from copying any answers to make the most out of the assignment. If any signs of plagiarism are detected, actions will be taken.
# - It is acceptable to share the workload of the assignment bearing the discussion in mind.
# - Feel free to [reach out](mailto:cmpsy27@gmail.com) if there were any ambiguities or post on the classroom.

# %% [markdown]
# ## Submission Instructions
#
# To ensure a smooth evaluation process, please follow these steps for submitting your work:
#
# 1. **Prepare Your Submission:** Alongside your main notebook, include any additional files that are necessary for running the notebook successfully. This might include data files, images, or supplementary scripts.
#
# 2. **Rename Your Files:** Before submission, please rename your notebook to reflect the IDs of the two students working on this assignment. The format should be `ID1_ID2`, where `ID1` and `ID2` are the student IDs. For example, if the student IDs are `9123456` and `9876543`, then your notebook should be named `9123456_9876543.ipynb`.
#
# 3. **Check for Completeness:** Ensure that all required tasks are completed and that the notebook runs from start to finish without errors. This step is crucial for a smooth evaluation.
#
# 4. **Submit Your Work:** Once everything is in order, submit your notebook and any additional files via the designated submission link on Google Classroom **(code: 2yj6e24)**. Make sure you meet the submission deadline to avoid any late penalties.
# 5. Please, note that the same student should submit the assignments for the pair throughout the semester.
#
# By following these instructions carefully, you help us in evaluating your work efficiently and fairly **and any failure to adhere to these guidelines can affect your grades**. If you encounter any difficulties or have questions about the submission process, please reach out as soon as possible.
#
# We look forward to seeing your completed assignments and wish you the best of luck!

# %% [markdown]
# ## Installation Instructions
#
# In this lab assignment, we require additional Python libraries for machine learning (ML) and deep learning (DL) algorithms and frameworks. To fulfill these requirements, we need to install Pytorch.
# 1. Install Pytorch \
# PyTorch is a versatile and powerful machine learning library for Python, known for its flexibility and ease of use in research and production. It supports various deep learning operations and models, including convolutional and recurrent neural networks. For Windows users, the installation also requires ensuring that CUDA, provided by NVIDIA, is compatible to enable GPU acceleration. This enhances performance significantly, particularly in training large neural networks.\
# For windows installation with GPU support you can [check out this link](https://pytorch.org/get-started/locally/) which is the source for the command below and please know that support for GPU is done for windows so you can also check out [previous versions](https://pytorch.org/get-started/previous-versions/), you could use CPU on windows smoothly, use linux or resort to [WSL](https://www.youtube.com/watch?v=R4m8YEixidI).
#
# ```bash
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# ```
# ```bash
# conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
# ```

# %% [markdown]
# > **Note:** You are allowed to install any other necessary libraries you deem useful for solving the lab. Please ensure that any additional libraries are compatible with the assignment requirements and are properly documented in your submission.

# %% [markdown]
# ## U-Net
#
# U-Net is a convolutional neural network designed specifically for biomedical image segmentation. First introduced in a 2015 paper by Olaf Ronneberger, Philipp Fischer, and Thomas Brox, its architecture is notably shaped like the letter "U", which inspired its name. This structure comprises a contracting path to capture context and a symmetrically expanding path that aids in precise localization, making it particularly adept at leveraging small datasets to achieve highly accurate segmentations. U-Net's ability to accurately segment various tissues and medical conditions has made it a staple in medical imaging and has spurred adaptations for broader image analysis applications. Its success in the medical domain demonstrates its potential for high-impact applications in other fields requiring detailed image segmentation.
#
# U-Net's robust architecture has found significant applications in the field of satellite imaging as well. The ability of U-Net to effectively handle multi-scale and high-resolution images makes it particularly suitable for satellite image analysis. In satellite imaging, U-Net is commonly used for tasks such as land cover classification, road detection, and building segmentation. Its structure allows for precise segmentation of complex objects from high-resolution satellite imagery, even with relatively limited labeled datasets. This capability is crucial in environmental monitoring, urban planning, and disaster management, where accurate and detailed image analysis is required. The adaptability and efficiency of U-Net in handling spatial hierarchies and various textures present in satellite images highlight its versatility and effectiveness beyond its initial medical context.

# %% [markdown]
# ### U-Net Architecture
#
# ![U-Net Architecture](unet.jpg)

# %% [markdown]
# ### Detailed Overview of Functions in `utilities.py`
#
# The `utilities.py` file contains multiple functions to support image processing, data manipulation, and neural network training:
#
# - **`generate_random_data(height, width, count)`**:
#   - Generates random images and masks.
#
# - **`generate_img_and_mask(height, width)`**:
#   - Generates a single image and corresponding mask.
#
# - **`add_square(img, mask)`**:
#   - Adds a square to an image and updates the mask.
#
# - **`add_filled_square(img, mask)`**:
#   - Adds a filled square to an image and updates the mask.
#
# - **`logical_and(mask1, mask2)`**:
#   - Performs logical 'AND' operation between two masks.
#
# - **`add_mesh_square(img, mask)`**:
#   - Adds a mesh-patterned square to an image and updates the mask.
#
# - **`add_triangle(img, mask)`**:
#   - Adds a triangle to an image and updates the mask.
#
# - **`add_circle(img, mask)`**:
#   - Adds a circle to an image and updates the mask.
#
# - **`add_plus(img, mask)`**:
#   - Adds a plus sign to an image and updates the mask.
#
# - **`get_random_location(shape, zoom)`**:
#   - Gets a random location within an image shape.
#
# - **`plot_img_array(img_array, n_col)`**:
#   - Plots an array of images.
#
# - **`plot_side_by_side(img_arrays)`**:
#   - Plots images side by side for comparison.
#
# - **`plot_errors(train_losses, val_losses)`**:
#   - Plots training and validation loss errors.
#
# - **`masks_to_colorimg(masks)`**:
#   - Converts masks to colored images.
#
# - **`generate_images_and_masks_then_plot()`**:
#   - Generates images and masks and plots them.
#
# - **`reverse_transform(transform)`**:
#   - Reverses a transformation applied to an image.
#
# - **`get_data_loaders(train_dir, valid_dir, batch_size)`**:
#   - Gets data loaders for training and validation datasets.
#
# - **`dice_loss(inputs, targets, smooth)`**:
#   - Calculates Dice loss for model evaluation.
#
# - **`calc_loss(pred, target, metrics)`**:
#   - Calculates loss and updates metrics.
#
# - **`print_metrics(metrics, epoch_samples, phase)`**:
#   - Prints metrics for training or validation phases.
#
# - **`train_model(model, dataloaders, criterion, optimizer, num_epochs)`**:
#   - Trains a model given data loaders and training parameters.
#
# - **`run(model)`**:
#   - Runs a full model training and evaluation session.
#
# - **`__init__`, `__len__`, `__getitem__`**:
#   - Standard class methods used in Python classes, typically for data handling or model initialization.
#
# These functions collectively facilitate the full lifecycle of processing, training, and evaluating neural network models, particularly focusing on image-related tasks.

# %% [markdown]
# The primary objective of this assignment is to develop a neural network model capable of performing accurate image segmentation. Image segmentation involves dividing an image into segments that represent different objects or regions, which is crucial in various applications such as medical imaging, autonomous driving, and satellite image analysis.
#
# #### Image and Mask Generation
# In this assignment, synthetic images along with corresponding segmentation masks are generated to train and evaluate the segmentation model. Each image typically includes multiple geometric shapes placed randomly. These shapes can include simple forms such as circles, squares, and triangles, or more complex designs.
#
# #### Masks and Their Role in Segmentation
# - **Mask Generation**: Alongside each synthetic image, a mask is generated where each shape in the image has a corresponding segment in the mask. Each segment in the mask is represented by a unique color or grayscale intensity, where each intensity level corresponds to a different class (shape).
# - **Function of the Mask**: The mask serves as a "ground truth" for training the segmentation model. The model learns to predict these masks from the input images. Essentially, the task of the model is to map the input image to its corresponding output mask, segmenting the shapes it has learned during training.
# - **Learning Process**: During training, the model adjusts its parameters to minimize the difference between its predicted masks and the ground truth masks. This process involves optimizing a loss function, typically using backpropagation.

# %% [markdown]
# ## Requirement - U-Net Application
# - **Implement or Use U-Net**:
#   - **Option 1: Implementation** - Students are encouraged to implement the U-Net architecture from scratch, including defining all the layers and connections based on the standard specifications found in the literature.
#   - **Option 2: Use Pre-existing Implementation** - Students may also opt to use an existing implementation of U-Net. This can include adapting an open-source model available in frameworks like PyTorch.
#
# - **Integration with `utilities.py`**:
#   - The U-Net model, whether self-implemented or pre-existing, must be integrated with the `utilities.py` script provided. This integration is essential for processing data, training the model, and evaluating its performance efficiently.
#   - The model should effectively process input images and produce accurate segmentation masks as output, corresponding to the different segments of the input images.
#   - **You can make any necessary modifications including writing your own training loop for example**.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# import libraries here
import torch
import torch.nn as nn
from torchvision import models
from torch.nn.functional import relu,softmax
import sys

# %% [markdown]
# Convolution Size Rule
# ```
# Wout = (W-F+2P)/S+1
# ```
#
# UpConvolution Size Rule
# ```
# W = (Wout-1)*S+F-2P
# ```

# %%
class UNet(nn.Module):
    def __init__(self, n_class):
        super().__init__()
        # TODO: Define needed layers, use n_class variable in the last layer.'

        # Encoder (Contracting Path): down sampling the input image size while depth increases
        # Learning the WHAT (features) information in the image , but losing the WHERE (spatial) information
        # Each Block :
        #   1. Two 3*3 Convolutional Layer zero-padded with stride=1 Each Followed by a RELU Activation
        #   2. Max Pooling Layer 2*2 with stride=2 (Dimension halved)(Same Depth) [⬇ Down Sampling] [Except the last block :D]

        # input: 572x572x3  (192x192x3)
        self.e_1_conv_1= nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)   # 572x572x64  (192x192x64)
        self.e_1_conv_2= nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)  # 572x572x64  (192x192x64)
        self.e_1_pool= nn.MaxPool2d(kernel_size=2, stride=2)  # 286x286x64   (96x96x64)

        # input: 286x286x64   (96x96x64)
        self.e_2_conv_1= nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, bias=False)   # 286x286x128  (96,96,128)
        self.e_2_conv_2= nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1, bias=False)   # 286x286x128  (96,96,128)
        self.e_2_pool= nn.MaxPool2d(kernel_size=2, stride=2)  # 143x143x128   (48,48,128)


        # input: 143x143x128   (48,48,128)
        self.e_3_conv_1= nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False)   # 143x143x256   (48,48,256)
        self.e_3_conv_2= nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False)   # 143x143x256   (48,48,256)
        self.e_3_pool= nn.MaxPool2d(kernel_size=2, stride=2)  # 72x72x256*****     (24,24,256)


        # input: 72x72x256  (24,24,256)
        self.e_4_conv_1= nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=False)   # 72x72x512  (24x24x512)
        self.e_4_conv_2= nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1, bias=False)   # 72x72x512  (24x24x512)
        self.e_4_pool= nn.MaxPool2d(kernel_size=2, stride=2)  # 36x36x512   (12x12x512)


        # input: 36x36x512   (12x12x512)
        self.e_5_conv_1= nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, stride=1, padding=1, bias=False)   # 36x36x1024  (12x12x1024)
        self.e_5_conv_2= nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1, bias=False)   # 36x36x1024  (12x12x1024)
        # # No Max Pooling Layer


        # Decoder (Expansive Path): Up sampling feature maps to the original input image size, Size increases while Depth decreases
        # Learning the Where (spatial) information in the image.
        # Each Block :
        #   1. Up Convolution Layer 2*2 width stride=2 and zero pad (Dimension doubled)(Depth halved)[⬆ Up Sampling]
        #   2. Two 3*3 Convolutional Layer zero-padded with stride=1 Each Followed by a RELU Activation
        #   3. + Conv 1x1 @Last Block to reduce the depth to the number of classes

        # input: 36x36x1024  (12x12x1024)
        self.d_1_up= nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=2, stride=2, padding=0,output_padding=0, bias=False) # 72x72x512 (24x24x512)
        #  72x72x512[From Encoder] (24x24x512) + 72x72x512 (24x24x512) = 72x72x1024 (24x24x1024)
        self.d_1_conv_1= nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=3, stride=1, padding=1, bias=False) # 72x72x1024 (24x24x512)
        self.d_1_conv_2= nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1, bias=False)  # 72x72x1024 (24x24x512)

        # input:  72x72x1024 (24x24x512)
        self.d_2_up= nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2, padding=0,output_padding=0, bias=False) # 144x144x256  (48x48x256)
        #  143x143x256[From Encoder] (48,48,256) + 144x144x256  (48x48x256) = 144x144x512  (48x48x512)
        self.d_2_conv_1= nn.Conv2d(in_channels=512, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False) # 144x144x256  (48x48x256)
        self.d_2_conv_2= nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False) # 144x144x256  (48x48x256)

        # input:  144x144x256  (48x48x256)
        self.d_3_up= nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=2, stride=2, padding=0,output_padding=0, bias=False) # 288x288x128  (96x96x128)
        #  286x286x128  (96,96,128) [From Encoder] + 288x288x128  (96,96,128) = 288x288x256  (96,96,256)
        self.d_3_conv_1= nn.Conv2d(in_channels=256, out_channels=128, kernel_size=3, stride=1, padding=1, bias=False) # 288x288x128  (96,96,128)
        self.d_3_conv_2= nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1, bias=False) # 288x288x128  (96,96,128)

        # input:  288x288x128  (96,96,128)
        self.d_4_up= nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=2, stride=2, padding=0,output_padding=0, bias=False) # 576x576x64 (192x192x64)
        #  572x572x64  (192x192x64)[From Encoder] + 576x576x64 (192x192x64)  = 576x576x128  (192x192x128)
        self.d_4_conv_1= nn.Conv2d(in_channels=128, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False) # 576x576x64 (192x192x64)
        self.d_4_conv_2= nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)  # 576x576x64 (192x192x64)

        # input: 576x576x64 (192x192x64)
        self.d_4_conv_3= nn.Conv2d(in_channels=64, out_channels=n_class, kernel_size=1, stride=1, padding=0, bias=False) # 576x576xn_classes (192x192xn_classes)




    def forward(self, x):
        # TODO: Define forward function
        # Encoder (Contracting Path)
        x_e_1_conv_1 = relu(self.e_1_conv_1(x))
        x_e_1_conv_2 = relu(self.e_1_conv_2(x_e_1_conv_1))
        x_e_1_pool = self.e_1_pool(x_e_1_conv_2)

        x_e_2_conv_1 = relu(self.e_2_conv_1(x_e_1_pool))
        x_e_2_conv_2 = relu(self.e_2_conv_2(x_e_2_conv_1))
        x_e_2_pool = self.e_2_pool(x_e_2_conv_2)

        x_e_3_conv_1 = relu(self.e_3_conv_1(x_e_2_pool))
        x_e_3_conv_2 = relu(self.e_3_conv_2(x_e_3_conv_1))
        x_e_3_pool = self.e_3_pool(x_e_3_conv_2)

        x_e_4_conv_1 = relu(self.e_4_conv_1(x_e_3_pool))
        x_e_4_conv_2 = relu(self.e_4_conv_2(x_e_4_conv_1))
        x_e_4_pool = self.e_4_pool(x_e_4_conv_2)

        x_e_5_conv_1 = relu(self.e_5_conv_1(x_e_4_pool))
        x_e_5_conv_2 = relu(self.e_5_conv_2(x_e_5_conv_1))


        # Decoder
        x_d_1_up= self.d_1_up(x_e_5_conv_2)
        # crop_shape=x_d_1_up.shape
        # x_e_4_conv_2_cropped = x_e_4_conv_2[:, :, :crop_shape[2], :crop_shape[3]]
        x_d_1_up_concat = torch.cat([x_e_4_conv_2, x_d_1_up], dim=1)
        x_d_1_conv_1=relu(self.d_1_conv_1(x_d_1_up_concat))
        x_d_1_conv_2=relu(self.d_1_conv_2(x_d_1_conv_1))


        x_d_2_up= self.d_2_up(x_d_1_conv_2)
        # crop_shape=x_d_2_up.shape
        # x_e_3_conv_2_cropped = x_e_3_conv_2[:, :, :crop_shape[2], :crop_shape[3]]
        x_d_2_up_concat = torch.cat([x_e_3_conv_2, x_d_2_up], dim=1)
        x_d_2_conv_1=relu(self.d_2_conv_1(x_d_2_up_concat))
        x_d_2_conv_2=relu(self.d_2_conv_2(x_d_2_conv_1))

        x_d_3_up= self.d_3_up(x_d_2_conv_2)
        # crop_shape=x_d_3_up.shape
        # x_e_2_conv_2_cropped = x_e_2_conv_2[:, :, :crop_shape[2], :crop_shape[3]]
        x_d_3_up_concat = torch.cat([x_e_2_conv_2, x_d_3_up], dim=1)
        x_d_3_conv_1=relu(self.d_3_conv_1(x_d_3_up_concat))
        x_d_3_conv_2=relu(self.d_3_conv_2(x_d_3_conv_1))



        x_d_4_up= self.d_4_up(x_d_3_conv_2)
        # crop_shape=x_d_4_up.shape
        # x_e_1_conv_2_cropped = x_e_1_conv_2[:, :, :crop_shape[2], :crop_shape[3]]
        x_d_4_up_concat = torch.cat([x_e_1_conv_2, x_d_4_up], dim=1)
        x_d_4_conv_1=relu(self.d_4_conv_1(x_d_4_up_concat))
        x_d_4_conv_2=relu(self.d_4_conv_2(x_d_4_conv_1))

        # 1x1 CONV
        x_d_4_conv_3=self.d_4_conv_3(x_d_4_conv_2)

        output=x_d_4_conv_3

        # Apply softmax pixel-wise along the specified dimensions (usually channel dimension)
        # output = softmax(x_d_4_conv_3, dim=1)  # Apply softmax along the channel dimension

        # Assuming output is the softmax output
        # predicted_classes = torch.argmax(output, dim=1)
        # print(predicted_classes)
        # sys.exit()

        # Convert the predicted classes to binary masks
        # binary_masks = torch.zeros_like(predicted_classes)

        # # Set pixel values to 1 where the predicted class is not background (class index 0)
        # binary_masks[predicted_classes != 0] = 1


        return output

# %%
import utilities
import matplotlib.pyplot as plt

# Fine Tunning
# experiments=['Experiment(1)','Experiment(2)']
experiments=['Experiment(1)']
# learning_rates=[1e-1,1e-4]
learning_rates=[1e-4]
# step_sizes=[1,30]
step_sizes=[30]
gammas=[0.1]
# num_epochs=[10,60]
num_epochs=[60]
# bce_weights=[0.5,0.5]
bce_weights=[0.5]

train_loss_per_epoches={}
train_bce_loss_per_epoches={}
train_dice_loss_per_epoches={}
train_jacord_index_per_epoches={}

val_loss_per_epoches={}
val_bce_loss_per_epoches={}
val_dice_loss_per_epoches={}
val_jacord_index_per_epoches={}



for i in range(len(experiments)):
  loss_per_epoch,bce_loss_per_epoch,dice_loss_per_epoch,jacrod_index_per_epoch,loss_per_val_epoch,bce_loss_per_val_epoch,dice_loss_per_val_epoch,jacrod_index_per_val_epoch=utilities.run(UNet,lr=learning_rates[i],step_size=step_sizes[i]
                ,gamma=gammas[i]
                ,num_epochs=num_epochs[i]
                ,bce_weight=bce_weights[i])

  train_loss_per_epoches[experiments[i]]=loss_per_epoch
  train_bce_loss_per_epoches[experiments[i]]=bce_loss_per_epoch
  train_dice_loss_per_epoches[experiments[i]]=dice_loss_per_epoch
  train_jacord_index_per_epoches[experiments[i]]=jacrod_index_per_epoch


  val_loss_per_epoches[experiments[i]]=loss_per_val_epoch
  val_bce_loss_per_epoches[experiments[i]]=bce_loss_per_val_epoch
  val_dice_loss_per_epoches[experiments[i]]=dice_loss_per_val_epoch
  val_jacord_index_per_epoches[experiments[i]]=jacrod_index_per_val_epoch


# Draw Train Epoch loss
fig, axes = plt.subplots(1, 4, figsize=(18, 6))  # Adjust figsize as needed
utilities.plot_errors(train_loss_per_epoches,title="Train Loss",x_label="epoch",y_label="loss",ax=axes[0])
utilities.plot_errors(train_bce_loss_per_epoches,title="Train BCE Loss",x_label="epoch",y_label="loss",ax=axes[1])
utilities.plot_errors(train_dice_loss_per_epoches,title="Train Dice Loss",x_label="epoch",y_label="loss",ax=axes[2])
utilities.plot_errors(val_jacord_index_per_epoches,title="Jacord Index",x_label="epoch",y_label="index",ax=axes[3])
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 4, figsize=(18, 6))  # Adjust figsize as needed
utilities.plot_errors(val_loss_per_epoches,title="Validation Loss",x_label="epoch",y_label="loss",ax=axes[0])
utilities.plot_errors(val_bce_loss_per_epoches,title="Validation BCE Loss",x_label="epoch",y_label="loss",ax=axes[1])
utilities.plot_errors(val_dice_loss_per_epoches,title="Validation Dice Loss",x_label="epoch",y_label="loss",ax=axes[2])
utilities.plot_errors(val_jacord_index_per_epoches,title="Jacord Index",x_label="epoch",y_label="index",ax=axes[3])

plt.tight_layout()
plt.show()
# Out:
# Epoch 0/59
# ----------
# LR 0.0001
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# saving best model
# 0m 3s
# Epoch 26/59
# ----------
# LR 0.0001
# train: bce: 0.026989, dice: 0.702057, loss: 0.364523, jaccrod_index: 0.815008
# val: bce: 0.023868, dice: 0.693048, loss: 0.358458, jaccrod_index: 0.808386
# saving best model
# 0m 3s
# Epoch 27/59
# ----------
# LR 0.0001
# train: bce: 0.026780, dice: 0.685470, loss: 0.356125, jaccrod_index: 0.802757
# val: bce: 0.023242, dice: 0.669565, loss: 0.346404, jaccrod_index: 0.791616
# saving best model
# 0m 3s
# Epoch 28/59
# ----------
# LR 0.0001
# train: bce: 0.025009, dice: 0.664242, loss: 0.344626, jaccrod_index: 0.786582
# val: bce: 0.022737, dice: 0.647016, loss: 0.334876, jaccrod_index: 0.774628
# saving best model
# 0m 3s
# Epoch 29/59
# ----------
# LR 1e-05
# train: bce: 0.024565, dice: 0.645469, loss: 0.335017, jaccrod_index: 0.771993
# val: bce: 0.022645, dice: 0.644245, loss: 0.333445, jaccrod_index: 0.772387
# saving best model
# 0m 3s
# Epoch 30/59
# ----------
# LR 1e-05
# train: bce: 0.024511, dice: 0.641931, loss: 0.333221, jaccrod_index: 0.769183
# val: bce: 0.022746, dice: 0.641074, loss: 0.331910, jaccrod_index: 0.769977
# saving best model
# 0m 3s
# Epoch 31/59
# ----------
# LR 1e-05
# train: bce: 0.024532, dice: 0.638904, loss: 0.331718, jaccrod_index: 0.766702
# val: bce: 0.022635, dice: 0.638468, loss: 0.330552, jaccrod_index: 0.767655
# saving best model
# 0m 3s
# Epoch 32/59
# ----------
# LR 1e-05
# train: bce: 0.024484, dice: 0.635540, loss: 0.330012, jaccrod_index: 0.763691
# val: bce: 0.022802, dice: 0.634913, loss: 0.328858, jaccrod_index: 0.764773
# saving best model
# 0m 3s
# Epoch 33/59
# ----------
# LR 1e-05
# train: bce: 0.024735, dice: 0.631942, loss: 0.328338, jaccrod_index: 0.760759
# val: bce: 0.023089, dice: 0.630874, loss: 0.326981, jaccrod_index: 0.761693
# saving best model
# 0m 3s
# Epoch 34/59
# ----------
# LR 1e-05
# train: bce: 0.025005, dice: 0.628394, loss: 0.326700, jaccrod_index: 0.757929
# val: bce: 0.023211, dice: 0.627551, loss: 0.325381, jaccrod_index: 0.758938
# saving best model
# 0m 3s
# Epoch 35/59
# ----------
# LR 1e-05
# train: bce: 0.025074, dice: 0.625070, loss: 0.325072, jaccrod_index: 0.754980
# val: bce: 0.023301, dice: 0.624401, loss: 0.323851, jaccrod_index: 0.756252
# saving best model
# 0m 3s
# Epoch 36/59
# ----------
# LR 1e-05
# train: bce: 0.025257, dice: 0.621596, loss: 0.323426, jaccrod_index: 0.752065
# val: bce: 0.023530, dice: 0.620632, loss: 0.322081, jaccrod_index: 0.753266
# saving best model
# 0m 3s
# Epoch 37/59
# ----------
# LR 1e-05
# train: bce: 0.025543, dice: 0.618244, loss: 0.321894, jaccrod_index: 0.749266
# val: bce: 0.023683, dice: 0.617114, loss: 0.320399, jaccrod_index: 0.750272
# saving best model
# 0m 3s
# Epoch 38/59
# ----------
# LR 1e-05
# train: bce: 0.025570, dice: 0.614903, loss: 0.320237, jaccrod_index: 0.746210
# val: bce: 0.023681, dice: 0.614322, loss: 0.319001, jaccrod_index: 0.747852
# saving best model
# 0m 3s
# Epoch 39/59
# ----------
# LR 1e-05
# train: bce: 0.025626, dice: 0.611782, loss: 0.318704, jaccrod_index: 0.743521
# val: bce: 0.023785, dice: 0.611100, loss: 0.317443, jaccrod_index: 0.745162
# saving best model
# 0m 3s
# Epoch 40/59
# ----------
# LR 1e-05
# train: bce: 0.025647, dice: 0.608592, loss: 0.317120, jaccrod_index: 0.740549
# val: bce: 0.023875, dice: 0.607734, loss: 0.315804, jaccrod_index: 0.742223
# saving best model
# 0m 3s
# Epoch 41/59
# ----------
# LR 1e-05
# train: bce: 0.025815, dice: 0.605302, loss: 0.315559, jaccrod_index: 0.737753
# val: bce: 0.024050, dice: 0.604161, loss: 0.314105, jaccrod_index: 0.739380
# saving best model
# 0m 3s
# Epoch 42/59
# ----------
# LR 1e-05
# train: bce: 0.025932, dice: 0.602074, loss: 0.314003, jaccrod_index: 0.734880
# val: bce: 0.024060, dice: 0.600899, loss: 0.312479, jaccrod_index: 0.736354
# saving best model
# 0m 3s
# Epoch 43/59
# ----------
# LR 1e-05
# train: bce: 0.025963, dice: 0.599110, loss: 0.312536, jaccrod_index: 0.732168
# val: bce: 0.024081, dice: 0.597750, loss: 0.310916, jaccrod_index: 0.733639
# saving best model
# 0m 3s
# Epoch 44/59
# ----------
# LR 1e-05
# train: bce: 0.025939, dice: 0.596199, loss: 0.311069, jaccrod_index: 0.729354
# val: bce: 0.024114, dice: 0.594760, loss: 0.309437, jaccrod_index: 0.731037
# saving best model
# 0m 3s
# Epoch 45/59
# ----------
# LR 1e-05
# train: bce: 0.026057, dice: 0.592952, loss: 0.309504, jaccrod_index: 0.726606
# val: bce: 0.024204, dice: 0.590951, loss: 0.307577, jaccrod_index: 0.727597
# saving best model
# 0m 3s
# Epoch 46/59
# ----------
# LR 1e-05
# train: bce: 0.026073, dice: 0.590068, loss: 0.308071, jaccrod_index: 0.723737
# val: bce: 0.024193, dice: 0.588414, loss: 0.306304, jaccrod_index: 0.725491
# saving best model
# 0m 3s
# Epoch 47/59
# ----------
# LR 1e-05
# train: bce: 0.026033, dice: 0.587143, loss: 0.306588, jaccrod_index: 0.721168

# %% [markdown]
# ### Test on Best Model (Fined Tuned)

# %%
utilities.run(UNet,lr=1e-4,step_size=30
                ,gamma=0.1
                ,num_epochs=60
                ,bce_weight=0.5,test=True)

# %%
utilities.run(UNet,lr=1e-4,step_size=30
                ,gamma=0.1
                ,num_epochs=100
                ,bce_weight=0.4,test=True)
# Out:
# Epoch 0/99
# ----------
# LR 0.0001
# train: bce: 0.703243, dice: 0.990108, loss: 0.875362, jaccrod_index: 0.994996
# val: bce: 0.690375, dice: 0.990947, loss: 0.870718, jaccrod_index: 0.995421
# saving best model
# 0m 3s
# Epoch 1/99
# ----------
# LR 0.0001
# train: bce: 0.684963, dice: 0.990063, loss: 0.868023, jaccrod_index: 0.994973
# saving best model
# 0m 3s
# Epoch 26/99
# ----------
# LR 0.0001
# train: bce: 0.026487, dice: 0.665533, loss: 0.409915, jaccrod_index: 0.788079
# val: bce: 0.024208, dice: 0.651918, loss: 0.400834, jaccrod_index: 0.778961
# saving best model
# 0m 3s
# Epoch 27/99
# ----------
# LR 0.0001
# train: bce: 0.025576, dice: 0.639903, loss: 0.394172, jaccrod_index: 0.766089
# val: bce: 0.023478, dice: 0.625235, loss: 0.384532, jaccrod_index: 0.755318
# saving best model
# 0m 3s
# Epoch 28/99
# ----------
# LR 0.0001
# train: bce: 0.025324, dice: 0.614609, loss: 0.378895, jaccrod_index: 0.742214
# val: bce: 0.022902, dice: 0.598781, loss: 0.368429, jaccrod_index: 0.729990
# saving best model
# 0m 3s
# Epoch 29/99
# ----------
# LR 1e-05
# train: bce: 0.024589, dice: 0.598745, loss: 0.369083, jaccrod_index: 0.726346
# val: bce: 0.022808, dice: 0.594761, loss: 0.365980, jaccrod_index: 0.726176
# saving best model
# 0m 3s
# Epoch 30/99
# ----------
# LR 1e-05
# train: bce: 0.024530, dice: 0.595640, loss: 0.367196, jaccrod_index: 0.723469
# val: bce: 0.022686, dice: 0.592816, loss: 0.364764, jaccrod_index: 0.724395
# saving best model
# 0m 3s
# Epoch 31/99
# ----------
# LR 1e-05
# train: bce: 0.024227, dice: 0.593106, loss: 0.365554, jaccrod_index: 0.720745
# val: bce: 0.022287, dice: 0.589580, loss: 0.362663, jaccrod_index: 0.720692
# saving best model
# 0m 3s
# Epoch 32/99
# ----------
# LR 1e-05
# train: bce: 0.023822, dice: 0.590927, loss: 0.364085, jaccrod_index: 0.718344
# val: bce: 0.021942, dice: 0.587038, loss: 0.361000, jaccrod_index: 0.718144
# saving best model
# 0m 3s
# Epoch 33/99
# ----------
# LR 1e-05
# train: bce: 0.023497, dice: 0.588381, loss: 0.362428, jaccrod_index: 0.715902
# val: bce: 0.021684, dice: 0.584744, loss: 0.359520, jaccrod_index: 0.716184
# saving best model
# 0m 3s
# Epoch 34/99
# ----------
# LR 1e-05
# train: bce: 0.023253, dice: 0.586152, loss: 0.360992, jaccrod_index: 0.713959
# val: bce: 0.021437, dice: 0.581902, loss: 0.357716, jaccrod_index: 0.713299
# saving best model
# 0m 3s
# Epoch 35/99
# ----------
# LR 1e-05
# train: bce: 0.023021, dice: 0.583614, loss: 0.359376, jaccrod_index: 0.711361
# val: bce: 0.021275, dice: 0.579243, loss: 0.356056, jaccrod_index: 0.710590
# saving best model
# 0m 3s
# Epoch 36/99
# ----------
# LR 1e-05
# train: bce: 0.022875, dice: 0.581294, loss: 0.357927, jaccrod_index: 0.709201
# val: bce: 0.021155, dice: 0.576596, loss: 0.354420, jaccrod_index: 0.708187
# saving best model
# 0m 3s
# Epoch 37/99
# ----------
# LR 1e-05
# train: bce: 0.022767, dice: 0.578852, loss: 0.356418, jaccrod_index: 0.707017
# val: bce: 0.021031, dice: 0.573966, loss: 0.352792, jaccrod_index: 0.705714
# saving best model
# 0m 3s
# Epoch 38/99
# ----------
# LR 1e-05
# train: bce: 0.022612, dice: 0.576358, loss: 0.354860, jaccrod_index: 0.704682
# val: bce: 0.020855, dice: 0.571301, loss: 0.351122, jaccrod_index: 0.703127
# saving best model
# 0m 3s
# Epoch 39/99
# ----------
# LR 1e-05
# train: bce: 0.022413, dice: 0.573965, loss: 0.353344, jaccrod_index: 0.702447
# val: bce: 0.020664, dice: 0.568705, loss: 0.349488, jaccrod_index: 0.700725
# saving best model
# 0m 3s
# Epoch 40/99
# ----------
# LR 1e-05
# val: bce: 0.020501, dice: 0.565959, loss: 0.347776, jaccrod_index: 0.698115
# saving best model
# 0m 3s
# Epoch 41/99
# ----------
# LR 1e-05
# train: bce: 0.022063, dice: 0.568859, loss: 0.350141, jaccrod_index: 0.697764
# val: bce: 0.020389, dice: 0.563120, loss: 0.346028, jaccrod_index: 0.695545
# saving best model
# 0m 3s
# Epoch 42/99
# ----------
# LR 1e-05
# train: bce: 0.021942, dice: 0.566136, loss: 0.348458, jaccrod_index: 0.695368
# val: bce: 0.020286, dice: 0.560197, loss: 0.344232, jaccrod_index: 0.692971
# saving best model
# 0m 3s
# Epoch 43/99
# ----------
# LR 1e-05
# train: bce: 0.021845, dice: 0.563319, loss: 0.346729, jaccrod_index: 0.692973
# val: bce: 0.020197, dice: 0.557109, loss: 0.342344, jaccrod_index: 0.690223
# saving best model
# 0m 3s
# Epoch 44/99
# ----------
# LR 1e-05
# train: bce: 0.021754, dice: 0.560519, loss: 0.345013, jaccrod_index: 0.690561
# val: bce: 0.020118, dice: 0.554114, loss: 0.340515, jaccrod_index: 0.687655
# saving best model
# 0m 3s
# Epoch 45/99
# ----------
# LR 1e-05
# train: bce: 0.021651, dice: 0.557381, loss: 0.343089, jaccrod_index: 0.687881
# val: bce: 0.020020, dice: 0.550878, loss: 0.338535, jaccrod_index: 0.684855
# saving best model
# 0m 3s
# Epoch 46/99
# ----------
# LR 1e-05
# train: bce: 0.021543, dice: 0.554307, loss: 0.341202, jaccrod_index: 0.685307
# val: bce: 0.019919, dice: 0.547613, loss: 0.336535, jaccrod_index: 0.682103
# saving best model
# 0m 3s
# Epoch 47/99
# ----------
# LR 1e-05
# train: bce: 0.021438, dice: 0.551096, loss: 0.339233, jaccrod_index: 0.682624
# val: bce: 0.019832, dice: 0.544226, loss: 0.334469, jaccrod_index: 0.679236
# saving best model
# 0m 3s
# Epoch 48/99
# ----------
# LR 1e-05
# train: bce: 0.021348, dice: 0.547812, loss: 0.337227, jaccrod_index: 0.679887
# val: bce: 0.019754, dice: 0.540602, loss: 0.332263, jaccrod_index: 0.676136
# saving best model
# 0m 3s
# Epoch 49/99
# ----------
# LR 1e-05
# train: bce: 0.021286, dice: 0.544391, loss: 0.335149, jaccrod_index: 0.677037
# val: bce: 0.019736, dice: 0.536995, loss: 0.330092, jaccrod_index: 0.673070
# saving best model
# 0m 3s
# Epoch 50/99
# ----------
# LR 1e-05
# train: bce: 0.021215, dice: 0.540864, loss: 0.333005, jaccrod_index: 0.674079
# val: bce: 0.019638, dice: 0.533547, loss: 0.327984, jaccrod_index: 0.670241
# saving best model
# 0m 3s
# Epoch 51/99
# ----------
# LR 1e-05
# train: bce: 0.021108, dice: 0.537346, loss: 0.330851, jaccrod_index: 0.671129
# val: bce: 0.019565, dice: 0.529152, loss: 0.325317, jaccrod_index: 0.666273
# saving best model
# 0m 3s
# Epoch 52/99
# ----------
# LR 1e-05
# train: bce: 0.021087, dice: 0.533586, loss: 0.328587, jaccrod_index: 0.667849
# val: bce: 0.019642, dice: 0.526375, loss: 0.323682, jaccrod_index: 0.664027
# saving best model
# 0m 3s
# Epoch 53/99
# ----------
# LR 1e-05
# train: bce: 0.021095, dice: 0.530120, loss: 0.326510, jaccrod_index: 0.664837
# val: bce: 0.019552, dice: 0.521630, loss: 0.320799, jaccrod_index: 0.659672
# saving best model
# 0m 3s
# Epoch 54/99
# ----------
# LR 1e-05
# train: bce: 0.021022, dice: 0.526285, loss: 0.324180, jaccrod_index: 0.661439
# val: bce: 0.019562, dice: 0.518792, loss: 0.319100, jaccrod_index: 0.657338
# saving best model
# 0m 3s
# Epoch 55/99
# ----------
# LR 1e-05
# train: bce: 0.021034, dice: 0.523084, loss: 0.322264, jaccrod_index: 0.658656
# val: bce: 0.019589, dice: 0.515191, loss: 0.316950, jaccrod_index: 0.654022
# saving best model
# 0m 3s
# Epoch 56/99
# ----------
# LR 1e-05
# train: bce: 0.021053, dice: 0.519448, loss: 0.320090, jaccrod_index: 0.655267
# val: bce: 0.019595, dice: 0.510670, loss: 0.314240, jaccrod_index: 0.649601
# saving best model
# 0m 3s
# Epoch 57/99
# ----------
# LR 1e-05
# train: bce: 0.021026, dice: 0.516018, loss: 0.318021, jaccrod_index: 0.652066
# val: bce: 0.019592, dice: 0.508347, loss: 0.312845, jaccrod_index: 0.647736
# saving best model
# 0m 3s
# Epoch 58/99
# ----------
# LR 1e-05
# train: bce: 0.021077, dice: 0.512766, loss: 0.316091, jaccrod_index: 0.648956
# val: bce: 0.019683, dice: 0.504115, loss: 0.310342, jaccrod_index: 0.643416
# saving best model
# 0m 3s
# Epoch 59/99
# ----------
# LR 1.0000000000000002e-06
# train: bce: 0.021141, dice: 0.510324, loss: 0.314651, jaccrod_index: 0.646634
# val: bce: 0.019696, dice: 0.504104, loss: 0.310341, jaccrod_index: 0.643441
# saving best model
# 0m 3s
# Epoch 60/99
# ----------
# LR 1.0000000000000002e-06
# train: bce: 0.021140, dice: 0.510009, loss: 0.314461, jaccrod_index: 0.646327
# val: bce: 0.019690, dice: 0.503772, loss: 0.310139, jaccrod_index: 0.643131
# saving best model
# 0m 3s
# Epoch 61/99
# ----------
# LR 1.0000000000000002e-06
# train: bce: 0.021130, dice: 0.509699, loss: 0.314272, jaccrod_index: 0.646036
# val: bce: 0.019678, dice: 0.503496, loss: 0.309969, jaccrod_index: 0.642887
# saving best model
# 0m 3s
# Epoch 62/99
# ----------
# LR 1.0000000000000002e-06
# train: bce: 0.021119, dice: 0.509392, loss: 0.314083, jaccrod_index: 0.645737
# val: bce: 0.019660, dice: 0.502953, loss: 0.309636, jaccrod_index: 0.642340
# saving best model
# 0m 3s
# Epoch 63/99
# ----------
# LR 1.0000000000000002e-06
# train: bce: 0.021113, dice: 0.509088, loss: 0.313898, jaccrod_index: 0.645424
# val: bce: 0.019655, dice: 0.502562, loss: 0.309399, jaccrod_index: 0.641950
# saving best model
# 0m 3s
# Epoch 64/99
# ----------
# LR 1.0000000000000002e-06
# train: bce: 0.
99
# ----------
# LR 1.0000000000000002e-07
# train: bce: 0.021175, dice: 0.501815, loss: 0.309559, jaccrod_index: 0.638224
# val: bce: 0.019737, dice: 0.495684, loss: 0.305305, jaccrod_index: 0.635098
# 0m 3s
# Epoch 95/99
# ----------
# LR 1.0000000000000002e-07
# train: bce: 0.021175, dice: 0.501788, loss: 0.309543, jaccrod_index: 0.638200
# val: bce: 0.019738, dice: 0.495685, loss: 0.305306, jaccrod_index: 0.635101
# 0m 3s
# Epoch 96/99
# ----------
# LR 1.0000000000000002e-07
# train: bce: 0.021176, dice: 0.501765, loss: 0.309529, jaccrod_index: 0.638177
# val: bce: 0.019739, dice: 0.495689, loss: 0.305309, jaccrod_index: 0.635109
# 0m 3s
# Epoch 97/99
# ----------
# LR 1.0000000000000002e-07
# train: bce: 0.021176, dice: 0.501738, loss: 0.309513, jaccrod_index: 0.638152
# val: bce: 0.019740, dice: 0.495657, loss: 0.305290, jaccrod_index: 0.635075
# saving best model
# 0m 3s
# Epoch 98/99
# ----------
# LR 1.0000000000000002e-07
# train: bce: 0.021177, dice: 0.501712, loss: 0.309498, jaccrod_index: 0.638126
# val: bce: 0.019740, dice: 0.495650, loss: 0.305286, jaccrod_index: 0.635070
# saving best model
# 0m 3s
# Epoch 99/99
# ----------
# LR 1.0000000000000002e-07
# train: bce: 0.021177, dice: 0.501689, loss: 0.309484, jaccrod_index: 0.638104
# val: bce: 0.019742, dice: 0.495637, loss: 0.305279, jaccrod_index: 0.635057
# saving best model
# 0m 3s
# Best val loss: 0.305279
# Done Training
# Testting Model
# Testing Model
# 0/1
# Test: DiceLoss : 0.4980427026748657 Dice Score: 0.5019572973251343 Jaccord Index: 0.6371909379959106
# Test(Sample): DiceLoss : 0.4817958474159241 Dice Score: 0.5182041525840759 Jaccord Index: 0.6198100447654724

# %%
utilities.run(UNet,lr=1e-2,step_size=30
                ,gamma=0.1
                ,num_epochs=200
                ,bce_weight=0.5,test=True)
# Out:
# Epoch 0/199
# ----------
# LR 0.01
# train: bce: 128.412652, dice: 0.991852, loss: 64.702252, jaccrod_index: 0.993928
# val: bce: 98.909019, dice: 0.990989, loss: 49.950005, jaccrod_index: 0.995442
# saving best model
# 0m 3s
# Epoch 1/199
# ----------
# LR 0.01
# train: bce: 140813593.205239, dice: 0.990305, loss: 70406796.973874, jaccrod_index: 0.994290
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# saving best model
# 0m 3s
# Epoch 2/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 218014480.000000, dice: 0.991027, loss: 109007240.000000, jaccrod_index: 0.995462
# 0m 3s
# Epoch 3/199
# ----------
# LR 0.01
# train: bce: 54456120.519861, dice: 0.990125, loss: 27228060.631221, jaccrod_index: 0.995004
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 4/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 5/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 120706039808.000000, dice: 0.990903, loss: 60353019904.000000, jaccrod_index: 0.995398
# 0m 3s
# Epoch 6/199
# ----------
# LR 0.01
# train: bce: 30821404672.546356, dice: 0.990090, loss: 15410702336.644487, jaccrod_index: 0.994987
# val: bce: 0.693138, dice: 0.990978, loss: 0.842058, jaccrod_index: 0.995436
# saving best model
# 0m 3s
# Epoch 7/199
# ----------
# LR 0.01
# train: bce: 17794240.531271, dice: 0.991257, loss: 8897120.636894, jaccrod_index: 0.994954
# val: bce: 0.692327, dice: 0.990977, loss: 0.841652, jaccrod_index: 0.995436
# saving best model
# 0m 3s
# Epoch 8/199
# ----------
# LR 0.01
# train: bce: 0.690566, dice: 0.990080, loss: 0.840323, jaccrod_index: 0.994981
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 9/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 10/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 11/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 12/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 13/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 14/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 15/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 16/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 17/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 18/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 19/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 20/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 21/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 22/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 23/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 24/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 25/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 26/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 27/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 28/199
# ----------
# LR 0.01
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 29/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 30/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 31/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 32/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 33/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 34/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 35/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 36/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 37/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 38/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 39/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 40/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 41/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 42/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 43/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 44/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 45/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 46/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 47/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 48/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 49/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 50/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 51/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 52/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 53/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 54/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 55/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 56/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 57/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 58/199
# ----------
# LR 0.001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 59/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 60/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 61/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 62/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 63/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 64/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 65/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 66/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 67/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 68/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 69/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 70/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 71/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 72/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 73/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 74/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 75/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 76/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 77/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 78/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 79/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 80/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 81/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 82/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 83/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 84/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 85/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 86/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 87/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 88/199
# ----------
# LR 0.0001
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 89/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 90/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 91/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 92/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 93/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 94/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 95/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 96/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 97/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 98/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 99/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 100/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 101/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 102/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 103/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 104/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 105/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 106/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 107/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 108/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 109/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 110/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 111/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 112/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 113/199
# ----------
# LR 1e-05
# train: bce: 0.693147, dice: 0.990112, loss: 0.841630, jaccrod_index: 0.994998
# val: bce: 0.693147, dice: 0.990978, loss: 0.842063, jaccrod_index: 0.995436
# 0m 3s
# Epoch 114/199
# ----------
# LR 1e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-2fca7b68bbc4> in <cell line: 1>()
# ----> 1 utilities.run(UNet,lr=1e-2,step_size=30
#       2                 ,gamma=0.1
#       3                 ,num_epochs=200
#       4                 ,bce_weight=0.5,test=True)
#
# /content/utilities.py in run(UNet, lr, step_size, gamma, num_epochs, bce_weight, test)
#     477     exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=step_size, gamma=gamma)
#     478
# --> 479     model,test_dataloader,loss_per_epoch,bce_loss_per_epoch,dice_loss_per_epoch,jacord_index_per_epoch,loss_per_val_epoch,bce_loss_per_val_epoch,dice_loss_per_val_epoch,jacord_index_per_val_epoch = train_model(model, optimizer_ft, exp_lr_scheduler, bce_weight=bce_weight, num_epochs=num_epochs)
#     480     print("Done Training")
#     481
#
# /content/utilities.py in train_model(model, optimizer, scheduler, bce_weight, num_epochs)
#     367
#     368             for inputs, labels in dataloaders[phase]:
# --> 369                 inputs = inputs.to(device)
#     370                 labels = labels.to(device)
#     371
#
# KeyboardInterrupt:

# %%
utilities.run(UNet,lr=1e-5,step_size=30
                ,gamma=0.1
                ,num_epochs=90
                ,bce_weight=0.35,test=True)
# Out:
# Epoch 0/89
# ----------
# LR 1e-05
# train: bce: 0.692958, dice: 0.990708, loss: 0.886495, jaccrod_index: 0.995300
# val: bce: 0.692096, dice: 0.990443, loss: 0.886021, jaccrod_index: 0.995165
# saving best model
# 0m 3s
# Epoch 1/89
# ----------
# LR 1e-05
# train: bce: 0.691636, dice: 0.990700, loss: 0.886028, jaccrod_index: 0.995296
# val: bce: 0.690884, dice: 0.990436, loss: 0.885592, jaccrod_index: 0.995162
# saving best model
# 0m 3s
# Epoch 2/89
# ----------
# LR 1e-05
# train: bce: 0.690424, dice: 0.990692, loss: 0.885599, jaccrod_index: 0.995292
# val: bce: 0.689668, dice: 0.990428, loss: 0.885162, jaccrod_index: 0.995158
# saving best model
# 0m 3s
# Epoch 3/89
# ----------
# LR 1e-05
89
# ----------
# LR 1.0000000000000002e-07
# train: bce: 0.106851, dice: 0.996249, loss: 0.684959, jaccrod_index: 0.997756
# val: bce: 0.106968, dice: 0.996150, loss: 0.684936, jaccrod_index: 0.997705
# saving best model
# 0m 3s
# Epoch 88/89
# ----------
# LR 1.0000000000000002e-07
# train: bce: 0.106315, dice: 0.996267, loss: 0.684784, jaccrod_index: 0.997762
# val: bce: 0.106438, dice: 0.996169, loss: 0.684763, jaccrod_index: 0.997712
# saving best model
# 0m 3s
# Epoch 89/89
# ----------
# LR 1.0000000000000004e-08
# train: bce: 0.105963, dice: 0.996279, loss: 0.684669, jaccrod_index: 0.997766
# val: bce: 0.106386, dice: 0.996171, loss: 0.684746, jaccrod_index: 0.997712
# saving best model
# 0m 3s
# Best val loss: 0.684746
# Done Training
# Testting Model
# Testing Model
# 0/1
# Test: DiceLoss : 0.9964064955711365 Dice Score: 0.0035935044288635254 Jaccord Index: 0.9978305101394653
# Test(Sample): DiceLoss : 0.996425211429596 Dice Score: 0.0035747885704040527 Jaccord Index: 0.9978397488594055

# %%
# Clear GPU cache
torch.cuda.empty_cache()

# %% [markdown]
# ### Grading Rubric (Total: 10 Marks)
#
# The lab is graded based on the following criteria:
#
# 1. **Data Loading and Preparation (1 Mark)**
#    - Ensure reproducible results by setting seed to `27` before all randomized operations. (1 Mark)
#
# 2. **U-Net Architecture (4 Marks)**
#    - Uses appropriate U-Net Architecture to the problem with a full pipeline. (4 Marks)
#
# 3. **Hyperparameters Tuning (2 Marks)**
#    - Report evaluation metrics on validation set. (1 Mark)
#    - Analyzes results and tunes hyperparameters. (1 Mark)
#
# 4. **Model Evaluation and Understanding (3 Marks)**
#    - Reports Jaccard Index and Dice Scores for test set. (1 Mark)
#    - **Comparison amongst your peers.** Compares the model's performance against those of peers to identify strengths and areas for improvement. (2 Marks)
#
# Each section of the lab will be evaluated on completeness, and correctness in approach and analysis. Part of the rubric also includes the student's ability to explain and justify their choices and results.

# %% [markdown]
# ## Submission Instructions
#
# To ensure a smooth evaluation process, please follow these steps for submitting your work:
#
# 1. **Prepare Your Submission:** Alongside your main notebook, include any additional files that are necessary for running the notebook successfully. This might include data files, images, or supplementary scripts.
#
# 2. **Rename Your Files:** Before submission, please rename your notebook to reflect the IDs of the two students working on this project. The format should be `ID1_ID2`, where `ID1` and `ID2` are the student IDs. For example, if the student IDs are `9123456` and `9876543`, then your notebook should be named `9123456_9876543.ipynb`.
#
# 3. **Check for Completeness:** Ensure that all required tasks are completed and that the notebook runs from start to finish without errors. This step is crucial for a smooth evaluation.
#
# 4. **Submit Your Work:** Once everything is in order, submit your notebook and any additional files via the designated submission link on Google Classroom **(code: 2yj6e24)**. Make sure you meet the submission deadline to avoid any late penalties.
# 5. Please, note that the same student should submit the assignments for the pair throughout the semester.
#
# By following these instructions carefully, you help us in evaluating your work efficiently and fairly **and any failure to adhere to these guidelines can affect your grades**. If you encounter any difficulties or have questions about the submission process, please reach out as soon as possible.
#
# We look forward to seeing your completed projects and wish you the best of luck!
